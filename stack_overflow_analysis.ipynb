# %%
import pandas as pd

# %%
df=pd.read_csv('stack_overflow_data_2019/survey_results_public.csv', index_col='Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
schema_df = pd.read_csv('stack_overflow_data_2019/survey_results_schema.csv', index_col='Column')

# %%
schema_df.tail(10)
# Out:
#                                                     QuestionText
# Column
# WelcomeChange  Compared to last year, how welcome do you feel...
# SONewContent   Would you like to see any of the following on ...
# Age            What is your age (in years)? If you prefer not...
# Gender         Which of the following do you currently identi...
# Trans                            Do you identify as transgender?
# Sexuality      Which of the following do you currently identi...
# Ethnicity      Which of the following do you identify as? Ple...
# Dependents     Do you have any dependents (e.g., children, el...
# SurveyLength   How do you feel about the length of the survey...
# SurveyEase     How easy or difficult was this survey to compl...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
# df.iloc[[0,1,2,3],'Hobbyist']

# %%
#df.loc[0:2,'Hobbyist':'Employment']

# %%
df.loc[0:2]['Hobbyist']

# %%
# df.set_index('email', inPlace=True) -- df.reset_index(inPlace=True)

df.loc[1]
# Out:
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
# Employment                 Not employed, and not looking for work
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 84, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']

# %%
schema_df.sort_index(ascending=False)

# %%
schema_df

# %%
filt = df['Hobbyist']=='Yes'

# %%
filt

# %%
df[filt]

# %%
df.loc[filt, 'Hobbyist']

# %%
filtt = (df['Hobbyist'] == 'Yes') & (df['Country'] == 'India')

# %%
df.loc[~filtt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
high_salary = (df['ConvertedComp'] >= 70000)

# %%
df.loc[high_salary, ['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States','India','Canada']
filt1 = df['Country'].isin(countries)

# %%
df.loc[filt1]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 6           I am not primarily a developer, but I write co...      Yes
# 8                                 I code primarily as a hobby      Yes
# 10                             I am a developer by profession      Yes
# 12                     I am a student who is learning to code       No
# ...                                                       ...      ...
# 85182                                                     NaN       No
# 85642                                                     NaN       No
# 86012                                                     NaN      Yes
# 88282                                                     NaN      Yes
# 88377                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
string_filter = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[string_filter]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
#df.columns = [x.lower() for x in df.columns] -- This will update the whole list
df.rename(columns={'Country':'Country list'}, inplace=True)

# %%
def upper_case(MainBranch):
    return MainBranch.upper()

# %%
df['Hobbyist'] = df['Hobbyist'].apply(lambda x: x.lower())

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        yes
# 2         no
# 3        yes
# 4         no
# 5        yes
#         ...
# 88377    yes
# 88601     no
# 88802     no
# 88816     no
# 88863    yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.apply(len)
# Out:
# MainBranch      88883
# Hobbyist        88883
# OpenSourcer     88883
# OpenSource      88883
# Employment      88883
#                 ...
# Sexuality       88883
# Ethnicity       88883
# Dependents      88883
# SurveyLength    88883
# SurveyEase      88883
# Length: 84, dtype: int64

# %%
# Out:
#   Cell In[137], line 1
#     git rm #cached stack_overflow_data_2019/survey_results_public.csv
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

import sys
sys.executable
# Out:
# '/Users/sauravrattu/opt/anaconda3/envs/data/bin/python'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["A", "B", "C"],
    "salary": [50000, 60000, 70000]
})

df
# Out:
#   name  salary
# 0    A   50000
# 1    B   60000
# 2    C   70000

# %%
## changing username and email
